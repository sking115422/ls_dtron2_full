# %% [markdown]
# ### Imports

# %%
import json
import os
import shutil
import random
import copy
from pandas.core.common import flatten
import numpy as np
import pandas as pd
from PIL import Image, ImageEnhance
import cv2
import albumentations as A
from collections import Counter
import time

# %% [markdown]
# ### Image Augmentation Functions

# %%
def getRandTup(low_low, low_high, high_low, high_high):

    rand_low = random.uniform(low_low,low_high)
    rand_high = random.uniform(high_low, high_high)
    rand_pick = random.uniform(0,1)
    
    rand_use = 0
    
    if rand_pick < .5:
        rand_use = rand_low
    else:
        rand_use = rand_high
        
    rand_tup = (rand_use, rand_use)
    
    return rand_tup

# %%
def aug_brightness(og_img):
        
    rand_tup = getRandTup(.3, .8, 2, 3.5)
        
    aug = A.ColorJitter(brightness=rand_tup,contrast=0,saturation=0,hue=0, always_apply=True, p=1)
    aug_img =  aug(image=og_img)['image']
    return aug_img

# %%
def aug_contrast(og_img):
    
    rand_tup = getRandTup(.3, .8, 2, 3.5)
        
    aug = A.ColorJitter(brightness=0,contrast=rand_tup,saturation=0,hue=0, always_apply=True, p=1)
    aug_img =  aug(image=og_img)['image']
    return aug_img

# %%
def aug_saturation(og_img):
    
    rand_tup = getRandTup(.3, .8, 2, 3.5)
        
    aug = A.ColorJitter(brightness=0,contrast=0,saturation=rand_tup,hue=0, always_apply=True, p=1)
    aug_img =  aug(image=og_img)['image']
    return aug_img

# %%
def aug_hue(og_img):
    
    rand_tup = getRandTup(-.5, -.075, .075, .5)
        
    aug = A.ColorJitter(brightness=0,contrast=0,saturation=0,hue=rand_tup, always_apply=True, p=1)
    aug_img =  aug(image=og_img)['image']
    return aug_img

# %%
def aug_color_jitter(og_img):
        
    aug = A.ColorJitter(brightness=getRandTup(.3, .8, 1.5, 2.25),
                        contrast=getRandTup(.3, .8, 1.5, 2.25),
                        saturation=getRandTup(.3, .8, 1.5, 2.25),
                        hue=getRandTup(-.5, -.075, .075, .5), 
                        always_apply=True, p=1)
    
    aug_img =  aug(image=og_img)['image']
    return aug_img

# %%
def aug_posterize(og_img):
    
    aug = A.Posterize(num_bits=(1,2), always_apply=True, p=1)
    
    aug_img =  aug(image=og_img)['image']
    return aug_img

# %%
def aug_blur(og_img):
    
    aug = A.Blur(blur_limit=(5, 9), always_apply=True, p=1)
    
    aug_img =  aug(image=og_img)['image']
    return aug_img

# %%
def createImgJson (img_id, fn):
    
    json_obj = {
        'width': 1920,
        'height': 1080,
        'id': img_id,
        'file_name': fn
    }
    
    return json_obj

# %%
def createAnnJson (ann_id, img_id, cat_id, seg, bbox, ignore, iscrowd, area):
    
    json_obj = {
        'id': ann_id,
        'image_id': img_id,
        'category_id': cat_id,
        'segmentation': seg,
        'bbox': bbox,
        'ignore': ignore,
        'iscrowd': iscrowd,
        'area': area
    }
    
    return json_obj

# %% [markdown]
# ### Annotation Stats Calculation Functions

# %%
def createCatMap (cat_list):
    cat_dict = {}
    for cat in cat_list:
        cat_dict.update({cat["id"]: cat["name"] })
    return cat_dict

# %%
def createImgAnnMap (img_list, ann_list):
    
    img_ann_dict = {}
    
    for img in img_list:
        tmp_ann_list = []
        for ann in ann_list:
            if ann["image_id"] == img["id"]:
                tmp_ann_list.append(ann)
        img_ann_dict.update({img["id"]: tmp_ann_list})
        
    return img_ann_dict

# %%
def calcImgStats (ann_list):
    
    tmp_cat_list = []
    for ann in ann_list:
        tmp_cat_list.append(ann["category_id"])
        
    return dict(Counter(tmp_cat_list))

# %%
def calcImgStatsAll (img_ann_map):
    
    img_stats_map = {}
    for i in range(0, len(img_ann_map)):
        ann_list = img_ann_map[i]
        img_stats_map.update({i: calcImgStats(ann_list)})
    
    return img_stats_map

# %%
def calcGlobStats (img_stats, cat_map):
    
    glob_stats = {}
        
    for key1 in range(0, len(cat_map)):
        total = 0
        for key2 in img_stats.keys():
            stats = img_stats[key2]
            try:
                total += stats[key1]
            except:
                pass
        glob_stats.update({key1: total})
        
    return glob_stats

# %% [markdown]
# ### Create Images Function

# %%
def createNewImgs(img_list, img_list_og, ann_list_og, cat_list_og):

    img_list_master = img_list_og
    ann_list_master = ann_list_og

    img_id_new = img_list_og[-1]["id"] + 1
    ann_id_new = ann_list_og[-1]["id"] + 1

    for i, img in enumerate(img_list):
        
        fn_rel = img["file_name"]
        fn = fn_rel[2:-4]
        fn_full = os.path.join(in_dir, "images", fn_rel[2:])
        img_id_og = img["id"]
        
        print (str(i) + ")", fn_full)
        
        # Creating directory for images inside of coco output file
        img_out_dir = os.path.join(out_dir, "images")
        os.makedirs(img_out_dir, exist_ok=True)
        
        # Collecting og annotations json
        ann_og = []
        for ann in ann_list_og:
            if img_id_og == ann["image_id"]:
                ann_og.append(ann)  
        
        ### FIX ###
        
        # Handling og images 
        og_img_path = os.path.join(img_out_dir, fn_rel)
        og_img = cv2.imread(fn_full)
        
        ann_new = []
        
        if adj_brightness > 0:
            for j in range(0, adj_brightness):
                fn_new = fn + "-bright-" + str(img_id_new) + ".png"
                bright_img_path = os.path.join(img_out_dir, fn_new)
                bright_img = aug_brightness(og_img)
                cv2.imwrite(bright_img_path, bright_img)
                
                img_list_master.append(createImgJson(img_id_new, "./" + fn_new))
                
                for ann in ann_og:
                    ann_new = createAnnJson(ann_id_new, img_id_new, ann["category_id"], ann["segmentation"], ann["bbox"], ann["ignore"], ann["iscrowd"], ann["area"])
                    ann_list_master.append(ann_new)
                    ann_id_new += 1
                
                img_id_new += 1
                
        if adj_contrast > 0:
            for j in range(0, adj_contrast):
                fn_new = fn + "-contrast-" + str(img_id_new) + ".png"
                contrast_img_path = os.path.join(img_out_dir, fn_new)
                contrast_img = aug_contrast(og_img)
                cv2.imwrite(contrast_img_path, contrast_img)
                
                img_list_master.append(createImgJson(img_id_new, "./" + fn_new))
                
                for ann in ann_og:
                    ann_new = createAnnJson(ann_id_new, img_id_new, ann["category_id"], ann["segmentation"], ann["bbox"], ann["ignore"], ann["iscrowd"], ann["area"])
                    ann_list_master.append(ann_new)
                    ann_id_new += 1
                
                img_id_new += 1
        
        if adj_saturation > 0:
            for j in range(0, adj_saturation):
                fn_new = fn + "-saturate-" + str(img_id_new) + ".png"
                saturate_img_path = os.path.join(img_out_dir, fn_new)
                saturate_img = aug_saturation(og_img)
                cv2.imwrite(saturate_img_path, saturate_img)
                
                img_list_master.append(createImgJson(img_id_new, "./" + fn_new))
                
                for ann in ann_og:
                    ann_new = createAnnJson(ann_id_new, img_id_new, ann["category_id"], ann["segmentation"], ann["bbox"], ann["ignore"], ann["iscrowd"], ann["area"])
                    ann_list_master.append(ann_new)
                    ann_id_new += 1
                
                img_id_new += 1

        if adj_hue > 0:
            for j in range(0, adj_hue):
                fn_new = fn + "-hue-" + str(img_id_new) + ".png"
                hue_img_path = os.path.join(img_out_dir, fn_new)
                hue_img = aug_hue(og_img)
                cv2.imwrite(hue_img_path, hue_img)
                
                img_list_master.append(createImgJson(img_id_new, "./" + fn_new))
                
                for ann in ann_og:
                    ann_new = createAnnJson(ann_id_new, img_id_new, ann["category_id"], ann["segmentation"], ann["bbox"], ann["ignore"], ann["iscrowd"], ann["area"])
                    ann_list_master.append(ann_new)
                    ann_id_new += 1
                
                img_id_new += 1

        if adj_color_jitter > 0:
            for j in range(0, adj_color_jitter):
                fn_new = fn + "-color_jitter-" + str(img_id_new) + ".png"
                color_jitter_img_path = os.path.join(img_out_dir, fn_new)
                color_jitter_img = aug_color_jitter(og_img)
                cv2.imwrite(color_jitter_img_path, color_jitter_img)
                
                img_list_master.append(createImgJson(img_id_new, "./" + fn_new))
                
                for ann in ann_og:
                    ann_new = createAnnJson(ann_id_new, img_id_new, ann["category_id"], ann["segmentation"], ann["bbox"], ann["ignore"], ann["iscrowd"], ann["area"])
                    ann_list_master.append(ann_new)
                    ann_id_new += 1
                
                img_id_new += 1
                
        if adj_posterize > 0:
            for j in range(0, adj_posterize):
                fn_new = fn + "-posterize-" + str(img_id_new) + ".png"
                posterize_img_path = os.path.join(img_out_dir, fn_new)
                posterize_img = aug_posterize(og_img)
                cv2.imwrite(posterize_img_path, posterize_img)
                
                img_list_master.append(createImgJson(img_id_new, "./" + fn_new))
                
                for ann in ann_og:
                    ann_new = createAnnJson(ann_id_new, img_id_new, ann["category_id"], ann["segmentation"], ann["bbox"], ann["ignore"], ann["iscrowd"], ann["area"])
                    ann_list_master.append(ann_new)
                    ann_id_new += 1
                
                img_id_new += 1
                
        if adj_blur > 0:
            for j in range(0, adj_blur):
                fn_new = fn + "-blur-" + str(img_id_new) + ".png"
                blur_img_path = os.path.join(img_out_dir, fn_new)
                blur_img = aug_blur(og_img)
                cv2.imwrite(blur_img_path, blur_img)
                
                img_list_master.append(createImgJson(img_id_new, "./" + fn_new))
                
                for ann in ann_og:
                    ann_new = createAnnJson(ann_id_new, img_id_new, ann["category_id"], ann["segmentation"], ann["bbox"], ann["ignore"], ann["iscrowd"], ann["area"])
                    ann_list_master.append(ann_new)
                    ann_id_new += 1
                
                img_id_new += 1
                
    json_out_obj = {
        "images": img_list_master,
        "categories": cat_list_og,
        "annotations": ann_list_master
    }

    # Writing out object
    jstr = json.dumps(json_out_obj, indent=4)
    with open(os.path.join(out_dir, "result.json"), "w+") as f:
        f.write(jstr)

# %% [markdown]
# ### Utility Functions

# %%
def getXRandValFromList(input_list, x, use_only_og):
    if use_only_og:
        filtered_list = [item for item in input_list if len(item["file_name"].split("-")) <= 2]
    else:
        filtered_list = input_list

    if x > len(filtered_list):
        print("Step size too large, defaulting to the smallest category list length.")
        return filtered_list
    else:
        return random.sample(filtered_list, x)

# %% [markdown]
# ### Global Variables

# %%
in_dir = "/mnt/nis_lab_research/data/coco_files/merged/far_shah_1247_v1"

# %%
out_dir = "/mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_us/"

# %%
# Number of images each category must have before program finishes
glob_upsamp_thold = 1000

# Number of random images chosen from min val list
step_size = 20

# Setting augmentation types
# Value is number of images of each type generated
# Augmented images generated per number of images chosen
# A value of 0 is off

adj_brightness = 1
adj_contrast = 1
adj_saturation = 1
adj_hue = 1
adj_color_jitter = 9
adj_posterize = 1
adj_blur = 1

# Flag to specific if only original images can be modified 
use_only_og = True

# Speed reduction threshold
# Threshold as which step size and augmentation types above become most conservative
speed_red_thold = .9

# %% [markdown]
# ## Main

# %%
if os.path.exists(out_dir):
    shutil.rmtree(out_dir)

shutil.copytree(in_dir, out_dir)
# Out:
# '/mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds_test/'

# %%
min_val = 0

while min_val < glob_upsamp_thold: 
    
    if min_val / glob_upsamp_thold > speed_red_thold:
        
        step_size = 5
        adj_brightness = 0
        adj_contrast = 0
        adj_saturation = 0
        adj_hue = 0
        adj_color_jitter = 1
        adj_posterize = 0
        adj_blur = 0

    with open(os.path.join(out_dir, "result.json")) as f:
        og_coco_obj = json.load(f)
        
    img_list_og = og_coco_obj["images"]
    ann_list_og = og_coco_obj["annotations"]
    cat_list_og = og_coco_obj["categories"] 

    cat_map = createCatMap(cat_list_og)
    img_ann_map = createImgAnnMap (img_list_og, ann_list_og)
    all_img_stats = calcImgStatsAll (img_ann_map)
    glob_stats = calcGlobStats (all_img_stats, cat_map)

    key_list = []
    val_list = []
    for key in glob_stats.keys():
        key_list.append(key)
        val_list.append(glob_stats[key])

    # Min none zero value
    min_val = min([x for x in val_list if x != 0])     
    min_val_key = key_list[val_list.index(min_val)]
    print(min_val_key, min_val)

    low_rep_img_id_list = []
    for ann in ann_list_og:
        if min_val_key == ann["category_id"]:
            low_rep_img_id_list.append(ann["image_id"])

    tmp_img_list = []
    for tmp_img_id in low_rep_img_id_list:        
        for img in img_list_og:
            if tmp_img_id == img["id"]:
                tmp_img_list.append(img)
                break
    
    input_imgs = getXRandValFromList (tmp_img_list, 1, use_only_og)
    
    createNewImgs(input_imgs, img_list_og, ann_list_og, cat_list_og)
# Out:
# 23 1
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/my4zSTtE0tVCgubv-nic_ss.png
# 12 2
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/2bkOIBYZoiizsIHD-genesisedu_ss.png
# 17 5
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/b6hxWvhDHrZFsRDw-1001fonts_ss.png
# 25 7
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/JogXj8fFjFULydeC-eset_ss.png
# 23 8
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/my4zSTtE0tVCgubv-nic_ss.png
# 12 9
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/2bkOIBYZoiizsIHD-genesisedu_ss.png
# 17 12
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/7hDuaqnPOVoDfg9I-toprankers_ss.png
# 25 14
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/K5wkeEBeLeoZGaT7-youporn_ss.png
# 23 15
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/my4zSTtE0tVCgubv-nic_ss.png
# 12 16
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/2bkOIBYZoiizsIHD-genesisedu_ss.png
# 17 19
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/7hDuaqnPOVoDfg9I-toprankers_ss.png
# 24 20
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/wbFUspEOT3q2r1fu-daad_ss.png
# 23 22
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/my4zSTtE0tVCgubv-nic_ss.png
# 12 23
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/mHTT7GU8rc0QxGye-douyin_ss.png
# 17 26
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/nLmsM77aOVcvIhbK-tomtop_ss.png
# 24 27
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/cBzwSOiMJMLzHQXG-newegg_ss.png
# 23 29
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/my4zSTtE0tVCgubv-nic_ss.png
# 12 30
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/mHTT7GU8rc0QxGye-douyin_ss.png
# 17 33
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/7hDuaqnPOVoDfg9I-toprankers_ss.png
# 24 34
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/k3fTUAUdKUDPZgiP-plos_ss.png
# 4 36
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/Fqi0amXCgmTtdYed-mdpi_ss.png
# 23 36
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/my4zSTtE0tVCgubv-nic_ss.png
# 12 37
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/2bkOIBYZoiizsIHD-genesisedu_ss.png
# 17 40
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/zq5RivQvKrPC9YSP-midwayusa_ss.png
# 6 41
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/DTmOy5MkkrthjevS-passcam_ss.png
# 25 42
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/K5wkeEBeLeoZGaT7-youporn_ss.png
# 23 43
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/my4zSTtE0tVCgubv-nic_ss.png
# 12 44
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/2bkOIBYZoiizsIHD-genesisedu_ss.png
# 1 45
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/GGtHay6NGF7c07pw-corel_ss.png
# 17 47
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/7hDuaqnPOVoDfg9I-toprankers_ss.png
# 6 48
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/nsY0QTnIlLNTBvBU-oecd_ss.png
# 4 50
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/Lra4Cz5ItpFMKKkA-ya_ss.png
# 23 50
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/my4zSTtE0tVCgubv-nic_ss.png
# 12 51
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/2bkOIBYZoiizsIHD-genesisedu_ss.png
# 17 54
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/7hDuaqnPOVoDfg9I-toprankers_ss.png
# 24 55
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/xCiaIPlW9PcMG7k1-criteo_ss.png
# 23 57
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/my4zSTtE0tVCgubv-nic_ss.png
# 12 58
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/mHTT7GU8rc0QxGye-douyin_ss.png
# 17 61
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/nLmsM77aOVcvIhbK-tomtop_ss.png
# 6 62
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/yj42Go3ZWDBqYxpg-udemy_ss.png
# 24 62
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/lbP9HUz7BRswnQf6-beatport_ss.png
# 23 64
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/my4zSTtE0tVCgubv-nic_ss.png
# 12 65
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/2bkOIBYZoiizsIHD-genesisedu_ss.png
# 1 66
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/HO2dndMNlZ8FFxZ5-9gag_ss.png
# 17 68
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/b6hxWvhDHrZFsRDw-1001fonts_ss.png
# 6 69
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/Yrw24UYHoMIm8uuy-crunchyroll_ss.png
# 25 70
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/xGMdBukImiKZNbwZ-playboyplus_ss.png
# 23 71
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/my4zSTtE0tVCgubv-nic_ss.png
# 12 72
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/2bkOIBYZoiizsIHD-genesisedu_ss.png
# 1 73
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/zYTCJOBE9sQiheq9-msn_ss.png
# 17 75
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/zq5RivQvKrPC9YSP-midwayusa_ss.png
# 6 76
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/bqB7kOxHQOBnnjJf-birchlane_ss.png
# 25 77
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/JogXj8fFjFULydeC-eset_ss.png
# 23 78
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/my4zSTtE0tVCgubv-nic_ss.png
# 12 79
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/2bkOIBYZoiizsIHD-genesisedu_ss.png
# 1 80
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/EKkls8OGnUzYe9sc-atcc_ss.png
# 17 82
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/nLmsM77aOVcvIhbK-tomtop_ss.png
# 6 83
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/FU1M7vBlCGY9dwW1-hostgator_ss.png
# 25 84
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/K5wkeEBeLeoZGaT7-youporn_ss.png
# 23 85
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/my4zSTtE0tVCgubv-nic_ss.png
# 12 86
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/2bkOIBYZoiizsIHD-genesisedu_ss.png
# 1 87
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/4OVGwGOApmxY0gyM-thebirthdaypartyproject_ss.png
# 17 89
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/yCQbNQEcOo3LqRpj-sony_ss.png
# 6 90
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/dkgbJejqDFuc9HX1-msweb_ss.png
# 24 90
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/w79kioNnEm9ySTZF-windows_ss.png
# 23 92
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/my4zSTtE0tVCgubv-nic_ss.png
# 12 93
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/mHTT7GU8rc0QxGye-douyin_ss.png
# 17 96
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/7hDuaqnPOVoDfg9I-toprankers_ss.png
# 6 97
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/c5jJ2DrGfPtSK52o-pexels_ss.png
# 24 97
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/ccp371zLIT5apAJC-mundijuegos_ss.png
# 23 99
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/my4zSTtE0tVCgubv-nic_ss.png
# 12 100
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/mHTT7GU8rc0QxGye-douyin_ss.png
# 17 103
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/zq5RivQvKrPC9YSP-midwayusa_ss.png
# 6 104
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/jMCRbqXxZoZjn3dL-ozon_ss.png
# 23 106
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/my4zSTtE0tVCgubv-nic_ss.png
# 12 107
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/mHTT7GU8rc0QxGye-douyin_ss.png
# 1 108
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/Yh0ToYNutbRFmYmY-sulekha_ss.png
# 17 110
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/zq5RivQvKrPC9YSP-midwayusa_ss.png
# 6 111
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/BhStHLl7v7ecKIbV-livemixtapes_ss.png
# 25 112
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/K5wkeEBeLeoZGaT7-youporn_ss.png
# 4 113
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/EKkls8OGnUzYe9sc-atcc_ss.png
# 23 113
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/my4zSTtE0tVCgubv-nic_ss.png
# 12 114
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/2bkOIBYZoiizsIHD-genesisedu_ss.png
# 17 117
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/b6hxWvhDHrZFsRDw-1001fonts_ss.png
# 6 118
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/WEFrKiakv6KQW9Gv-tandfonline_ss.png
# 23 120
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/my4zSTtE0tVCgubv-nic_ss.png
# 12 121
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/2bkOIBYZoiizsIHD-genesisedu_ss.png
# 1 122
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/Mzd4blYDuVA9GzN3-psychologytoday_ss.png
# 17 124
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/7hDuaqnPOVoDfg9I-toprankers_ss.png
# 6 125
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/XAAGg4Nz8DJkAnHr-science_ss.png
# 24 125
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/k3fTUAUdKUDPZgiP-plos_ss.png
# 4 127
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/Fqi0amXCgmTtdYed-mdpi_ss.png
# 23 127
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/my4zSTtE0tVCgubv-nic_ss.png
# 12 128
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/2bkOIBYZoiizsIHD-genesisedu_ss.png
# 17 131
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/zq5RivQvKrPC9YSP-midwayusa_ss.png
# 6 132
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/jMCRbqXxZoZjn3dL-ozon_ss.png
# 23 134
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/my4zSTtE0tVCgubv-nic_ss.png
# 12 135
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/2bkOIBYZoiizsIHD-genesisedu_ss.png
# 1 136
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/4OVGwGOApmxY0gyM-thebirthdaypartyproject_ss.png
# 17 138
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/nLmsM77aOVcvIhbK-tomtop_ss.png
# 6 139
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/lCw3zdzM7JmwCeIC-hdfcbank_ss.png
# 25 140
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/K5wkeEBeLeoZGaT7-youporn_ss.png
# 4 141
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/wmqsjTfBmPUWur2o-onetrust_ss.png
# 23 141
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/my4zSTtE0tVCgubv-nic_ss.png
# 12 142
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/2bkOIBYZoiizsIHD-genesisedu_ss.png
# 17 145
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/zq5RivQvKrPC9YSP-midwayusa_ss.png
# 6 146
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/6rMLrFmk7272xI3h-kickstarter_ss.png
# 24 146
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/w79kioNnEm9ySTZF-windows_ss.png
# 4 148
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/CnEyGq9CQB01ngAc-tubous_ss.png
# 23 148
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/my4zSTtE0tVCgubv-nic_ss.png
# 12 149
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/mHTT7GU8rc0QxGye-douyin_ss.png
# 1 150
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/ZAgZpkpFLgDsM6Ff-tripping_ss.png
# 17 152
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/nLmsM77aOVcvIhbK-tomtop_ss.png
# 6 153
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/LTSUTerz1jvvk98E-sciencemag_ss.png
# 24 153
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/k3fTUAUdKUDPZgiP-plos_ss.png
# 4 155
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/cstatbXGBPTpWesG-aodos_ss.png
# 23 155
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/my4zSTtE0tVCgubv-nic_ss.png
# 12 156
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/mHTT7GU8rc0QxGye-douyin_ss.png
# 1 157
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/EKkls8OGnUzYe9sc-atcc_ss.png
# 17 159
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/yCQbNQEcOo3LqRpj-sony_ss.png
# 6 160
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/c5jJ2DrGfPtSK52o-pexels_ss.png
# 23 162
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/my4zSTtE0tVCgubv-nic_ss.png
# 12 163
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/mHTT7GU8rc0QxGye-douyin_ss.png
# 1 164
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/JjeCMtXyG7pyxSId-wm_ss.png
# 17 166
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/zq5RivQvKrPC9YSP-midwayusa_ss.png
# 6 167
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/bqB7kOxHQOBnnjJf-birchlane_ss.png
# 25 168
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/JogXj8fFjFULydeC-eset_ss.png
# 23 169
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/my4zSTtE0tVCgubv-nic_ss.png
# 12 170
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/2bkOIBYZoiizsIHD-genesisedu_ss.png
# 1 171
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/MDdWlKJdlAVbKt2K-deskdemon_ss.png
# 17 173
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/b6hxWvhDHrZFsRDw-1001fonts_ss.png
# 6 174
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/3xm2yo1mEULeJz2E-nhentai_ss.png
# 24 174
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/k3fTUAUdKUDPZgiP-plos_ss.png
# 25 175
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/xGMdBukImiKZNbwZ-playboyplus_ss.png
# 23 176
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/my4zSTtE0tVCgubv-nic_ss.png
# 12 177
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/2bkOIBYZoiizsIHD-genesisedu_ss.png
# 1 178
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/o9UOORaF7ev8q8Iy-nursingpath_ss.png
# 17 180
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/nLmsM77aOVcvIhbK-tomtop_ss.png
# 6 181
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/zW1JB6fs5sR9IFo4-typepad_ss.png
# 25 182
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/usvKLt1Z1wOQM7JH-usatoday_ss.png
# 4 183
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/Fqi0amXCgmTtdYed-mdpi_ss.png
# 23 183
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/my4zSTtE0tVCgubv-nic_ss.png
# 12 184
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/2bkOIBYZoiizsIHD-genesisedu_ss.png
# 17 187
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/zq5RivQvKrPC9YSP-midwayusa_ss.png
# 6 188
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/Lra4Cz5ItpFMKKkA-ya_ss.png
# 25 189
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/K5wkeEBeLeoZGaT7-youporn_ss.png
# 23 190
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/my4zSTtE0tVCgubv-nic_ss.png
# 12 191
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/mHTT7GU8rc0QxGye-douyin_ss.png
# 17 194
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/b6hxWvhDHrZFsRDw-1001fonts_ss.png
# 6 195
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/pHzsulXBeBhznPyn-contentexchange_ss.png
# 24 195
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/k3fTUAUdKUDPZgiP-plos_ss.png
# 23 197
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/my4zSTtE0tVCgubv-nic_ss.png
# 12 198
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/2bkOIBYZoiizsIHD-genesisedu_ss.png
# 1 199
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/48JQ3zzE7wXJKWEL-nationalcar_ss.png
# 17 201
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/nLmsM77aOVcvIhbK-tomtop_ss.png
# 6 202
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/lgBjBwhNkKowXnK1-savefrom_ss.png
# 23 204
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/my4zSTtE0tVCgubv-nic_ss.png
# 12 205
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/mHTT7GU8rc0QxGye-douyin_ss.png
# 1 206
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/zYTCJOBE9sQiheq9-msn_ss.png
# 17 208
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/b6hxWvhDHrZFsRDw-1001fonts_ss.png
# 6 209
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/KvzGsHkilRUqnPI0-com_ss.png
# 4 211
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/lbP9HUz7BRswnQf6-beatport_ss.png
# 23 211
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/my4zSTtE0tVCgubv-nic_ss.png
# 12 212
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/mHTT7GU8rc0QxGye-douyin_ss.png
# 1 213
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/usvKLt1Z1wOQM7JH-usatoday_ss.png
# 17 215
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/7hDuaqnPOVoDfg9I-toprankers_ss.png
# 6 216
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/pHzsulXBeBhznPyn-contentexchange_ss.png
# 23 218
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/my4zSTtE0tVCgubv-nic_ss.png
# 12 219
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/2bkOIBYZoiizsIHD-genesisedu_ss.png
# 17 222
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/7hDuaqnPOVoDfg9I-toprankers_ss.png
# 6 223
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/lCw3zdzM7JmwCeIC-hdfcbank_ss.png
# 25 224
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/K5wkeEBeLeoZGaT7-youporn_ss.png
# 23 225
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/my4zSTtE0tVCgubv-nic_ss.png
# 12 226
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/mHTT7GU8rc0QxGye-douyin_ss.png
# 17 229
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/nLmsM77aOVcvIhbK-tomtop_ss.png
# 6 230
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/gL5pX5CXPnv1r57A-satellitesisters_ss.png
# 4 232
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/N2AhbEHoNTdCmAKV-kaspersky_ss.png
# 23 232
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/my4zSTtE0tVCgubv-nic_ss.png
# 12 233
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/mHTT7GU8rc0QxGye-douyin_ss.png
# 17 236
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/zq5RivQvKrPC9YSP-midwayusa_ss.png
# 6 237
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/6rMLrFmk7272xI3h-kickstarter_ss.png
# 4 239
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/NgYC10ir1JzrNp6N-cpanel_ss.png
# 23 239
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/my4zSTtE0tVCgubv-nic_ss.png
# 12 240
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/mHTT7GU8rc0QxGye-douyin_ss.png
# 1 241
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/EKkls8OGnUzYe9sc-atcc_ss.png
# 17 243
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/b6hxWvhDHrZFsRDw-1001fonts_ss.png
# 6 244
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/6rMLrFmk7272xI3h-kickstarter_ss.png
# 24 244
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/T0Dbp0JQHBKGzH5F-insightsonindia_ss.png
# 23 246
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/my4zSTtE0tVCgubv-nic_ss.png
# 12 247
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/2bkOIBYZoiizsIHD-genesisedu_ss.png
# 1 248
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/RCCr3waRheFrWWSE-com_ss.png
# 17 250
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/zq5RivQvKrPC9YSP-midwayusa_ss.png
# 6 251
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/IbrqtHvApd87MTDp-wayfair_ss.png
# 24 251
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/k3fTUAUdKUDPZgiP-plos_ss.png
# 25 252
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/K5wkeEBeLeoZGaT7-youporn_ss.png
# 23 253
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/my4zSTtE0tVCgubv-nic_ss.png
# 12 254
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/2bkOIBYZoiizsIHD-genesisedu_ss.png
# 1 255
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/ZAgZpkpFLgDsM6Ff-tripping_ss.png
# 17 257
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/yCQbNQEcOo3LqRpj-sony_ss.png
# 6 258
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/cpv0GOWXslaWiSZH-apa_ss.png
# 23 260
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/my4zSTtE0tVCgubv-nic_ss.png
# 12 261
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/2bkOIBYZoiizsIHD-genesisedu_ss.png
# 1 262
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/48JQ3zzE7wXJKWEL-nationalcar_ss.png
# 17 264
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/7hDuaqnPOVoDfg9I-toprankers_ss.png
# 6 265
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/gL5pX5CXPnv1r57A-satellitesisters_ss.png
# 4 267
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/Fqi0amXCgmTtdYed-mdpi_ss.png
# 23 267
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/my4zSTtE0tVCgubv-nic_ss.png
# 12 268
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/2bkOIBYZoiizsIHD-genesisedu_ss.png
# 17 271
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/7hDuaqnPOVoDfg9I-toprankers_ss.png
# 6 272
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/Lra4Cz5ItpFMKKkA-ya_ss.png
# 24 272
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/ccp371zLIT5apAJC-mundijuegos_ss.png
# 23 274
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/my4zSTtE0tVCgubv-nic_ss.png
# 12 275
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/2bkOIBYZoiizsIHD-genesisedu_ss.png
# 17 278
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/yCQbNQEcOo3LqRpj-sony_ss.png
# 6 279
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/KvzGsHkilRUqnPI0-com_ss.png
# 25 280
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/K5wkeEBeLeoZGaT7-youporn_ss.png
# 23 281
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/my4zSTtE0tVCgubv-nic_ss.png
# 12 282
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/mHTT7GU8rc0QxGye-douyin_ss.png
# 1 283
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/KFrvSdX4mLdIOoLQ-dvdvideosoft_ss.png
# 17 285
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/yCQbNQEcOo3LqRpj-sony_ss.png
# 6 286
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/nsY0QTnIlLNTBvBU-oecd_ss.png
# 23 288
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/my4zSTtE0tVCgubv-nic_ss.png
# 12 289
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/mHTT7GU8rc0QxGye-douyin_ss.png
# 1 290
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/GGtHay6NGF7c07pw-corel_ss.png
# 17 292
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/nLmsM77aOVcvIhbK-tomtop_ss.png
# 6 293
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/Cdt94uoWqKUuqZYw-upwork_ss.png
# 23 295
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/my4zSTtE0tVCgubv-nic_ss.png
# 12 296
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/2bkOIBYZoiizsIHD-genesisedu_ss.png
# 22 296
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/cPYK3kEsoFD2GYC4-princetonreview_ss.png
# 1 297
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/7hDuaqnPOVoDfg9I-toprankers_ss.png
# 6 300
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/6rMLrFmk7272xI3h-kickstarter_ss.png
# 24 300
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/ccp371zLIT5apAJC-mundijuegos_ss.png
# 23 302
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/my4zSTtE0tVCgubv-nic_ss.png
# 12 303
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/2bkOIBYZoiizsIHD-genesisedu_ss.png
# 1 304
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/LjLwb3rfbwlqviuJ-budget_ss.png
# 17 306
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/nLmsM77aOVcvIhbK-tomtop_ss.png
# 6 307
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/62YwK0Olua8VsJZy-bluehost_ss.png
# 25 308
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/xGMdBukImiKZNbwZ-playboyplus_ss.png
# 23 309
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/my4zSTtE0tVCgubv-nic_ss.png
# 12 310
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/2bkOIBYZoiizsIHD-genesisedu_ss.png
# 1 311
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/o9UOORaF7ev8q8Iy-nursingpath_ss.png
# 17 313
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/zq5RivQvKrPC9YSP-midwayusa_ss.png
# 6 314
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/BhStHLl7v7ecKIbV-livemixtapes_ss.png
# 25 315
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/K5wkeEBeLeoZGaT7-youporn_ss.png
# 23 316
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/my4zSTtE0tVCgubv-nic_ss.png
# 12 317
# 0) /mnt/nis_lab_research/data/coco_files/aug/far_shah_1247_v1_aug_ds/images/2bkOIBYZoiizsIHD-genesisedu_ss.png
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/home/dtron2_user/miniconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_35448/1692926249.py", line 24, in <module>
#     img_ann_map = createImgAnnMap (img_list_og, ann_list_og)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_35448/3022894661.py", line -1, in createImgAnnMap
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dtron2_user/miniconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 2144, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dtron2_user/miniconda3/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1435, in structured_traceback
#     return FormattedTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dtron2_user/miniconda3/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1326, in structured_traceback
#     return VerboseTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dtron2_user/miniconda3/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1173, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dtron2_user/miniconda3/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1088, in format_exception_as_a_whole
#     frames.append(self.format_record(record))
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dtron2_user/miniconda3/lib/python3.11/site-packages/IPython/core/ultratb.py", line 970, in format_record
#     frame_info.lines, Colors, self.has_colors, lvals
#     ^^^^^^^^^^^^^^^^
#   File "/home/dtron2_user/miniconda3/lib/python3.11/site-packages/IPython/core/ultratb.py", line 792, in lines
#     return self._sd.lines
#            ^^^^^^^^^^^^^^
#   File "/home/dtron2_user/miniconda3/lib/python3.11/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "/home/dtron2_user/miniconda3/lib/python3.11/site-packages/stack_data/core.py", line 734, in lines
#     pieces = self.included_pieces
#              ^^^^^^^^^^^^^^^^^^^^
#   File "/home/dtron2_user/miniconda3/lib/python3.11/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "/home/dtron2_user/miniconda3/lib/python3.11/site-packages/stack_data/core.py", line 681, in included_pieces
#     pos = scope_pieces.index(self.executing_piece)
#                              ^^^^^^^^^^^^^^^^^^^^
#   File "/home/dtron2_user/miniconda3/lib/python3.11/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "/home/dtron2_user/miniconda3/lib/python3.11/site-packages/stack_data/core.py", line 660, in executing_piece
#     return only(
#            ^^^^^
#   File "/home/dtron2_user/miniconda3/lib/python3.11/site-packages/executing/executing.py", line 116, in only
#     raise NotOneValueFound('Expected one value, found 0')
# executing.executing.NotOneValueFound: Expected one value, found 0
